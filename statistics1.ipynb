# %%
age = [23,34,56,81,95]
import numpy as np
np.var(age)
# Out:
# np.float64(740.56)

# %%
age = [23,56,90,93,96]
import numpy as np
np.std(age)
# Out:
# np.float64(28.274370019507067)

# %%
age = [16,18,20,23,34]
import seaborn as sns
sns.histplot(age,kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
mark = [50,60,70,80,90]
import numpy as np
np.mean(mark)
# Out:
# np.float64(70.0)

# %%
mark = [10,20,40,80,90]
import numpy as np
np.median(mark)
# Out:
# np.float64(40.0)
